# %%
import numpy as np
import sympy as sp
a = 2 * 10**5
ri = 2 * 10**6 # ohms
ro = 50 # ohms
r5 = 5 * 10**3 # ohms
r40 = 40 * 10**3 # ohms
r2 = 2 * 10**3 # ohms
vs = 1 # volts
v1, vo = sp.symbols('v1 v0')
n1 = sp.Eq(v1 / r5 + (v1 - v2) / r2 + (v1 - vo) / r40, 0)
n2 = sp.Eq((vo - ))
