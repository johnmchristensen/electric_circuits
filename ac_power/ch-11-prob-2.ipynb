# %%
from power import calc_average_power

c = -4j
l = 1j
i = 2
r = 5

i_r = i * (l + c) / (r + c + l)
v_r = i_r * r
p_r = abs(i_r)**2 * r
print("P_r = ", p_r, " W")
# Out:
# P_r =  5.294117647058824  W
