# %%
from ac_circuit_elements import to_capacitor_impedance, get_magnitude
from circuit_parallel import calc_par_imp
from power import mag2rms

w = 2000 # rad/s
r = 60 # ohms
c = 90 * 10 ** -6 # micro-F
z_c = to_capacitor_impedance(w, c) # Ohms
z = calc_par_imp(r, z_c)
v_s = mag2rms(160)
print("V = ", v_s, " V (RMS)")
i = v_s / z
p = abs(v_s)**2 / r
print("Load power: ", p , " W")
# Out:
# V =  113.1370849898476  V (RMS)
# Load power:  213.33333333333331  W
