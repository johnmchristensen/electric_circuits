# %%
from ac_circuit_elements import to_capacitor_impedance, to_inductor_impedance, to_phasor_string
from calcParImp import calcParImp

# %% [markdown]
# # Circuit A

# %%
omega = 5
c = to_capacitor_impedance(0.2, omega)
i = to_inductor_impedance(1, omega)
print(f"c = {c}")
print(f"i = {i}")
# Out:
# c = -1j
# i = 5j

# %%
z = calcParImp(i, c) + 8
print(f"z = {z}")
i = 75 / z
print(f"i = {i} = {to_phasor_string(i)}")
v0a = i * c
print(f"v0a = {v0a} = {to_phasor_string(v0a)}")
# Out:
# z = (8-1.25j)
# i = (9.151572926596758+1.4299332697807436j) = 9.262612816416576 @ 8.880659150520247
# v0a = (1.4299332697807436-9.151572926596758j) = 9.262612816416576 @ -81.11934084947976
